# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns

# %%
mtcars = pd.DataFrame(pd.read_csv("mtcars.csv"))
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars['mpg'].mean()
# Out:
# 20.090624999999996

# %%
mtcars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
norm_data = pd.DataFrame(np.random.normal(size = 100000))

norm_data.plot(kind = 'density', figsize = (10, 10))
plt.axhline(norm_data.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-744450857528> in <module>
#       2
#       3 norm_data.plot(kind = 'density', figsize = (10, 10))
# ----> 4 plt.axhline(norm_data.mean())
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in axhline(y, xmin, xmax, **kwargs)
#    2347 @_copy_docstring_and_deprecators(Axes.axhline)
#    2348 def axhline(y=0, xmin=0, xmax=1, **kwargs):
# -> 2349     return gca().axhline(y=y, xmin=xmin, xmax=xmax, **kwargs)
#    2350
#    2351
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in axhline(self, y, xmin, xmax, **kwargs)
#     732         # Strip away the units for comparison with non-unitized bounds.
#     733         yy, = self._process_unit_info([("y", y)], kwargs)
# --> 734         scaley = (yy < ymin) or (yy > ymax)
#     735
# ...

# %%
mtcars.mode()
# Out:
#                   model   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %%
max(mtcars['mpg']) - min(mtcars['mpg'])
# Out:
# 23.5

# %%
mtcars['mpg'].quantile(0.5)
# Out:
# 19.2

# %%
# Siempre coinciden los valores
mtcars['mpg'].median()
# Out:
# 19.2

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
mtcars.boxplot(column = 'mpg',
              return_type = 'axes')
# Out:
# <AxesSubplot:>

# %%
mtcars.var()
# Out:
# mpg        36.324103
# cyl         3.189516
# disp    15360.799829
# hp       4700.866935
# drat        0.285881
# wt          0.957379
# qsec        3.193166
# vs          0.254032
# am          0.248992
# gear        0.544355
# carb        2.608871
# dtype: float64

# %%
mtcars.std()
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
mtcars.kurt()
# Out:
# mpg    -0.022006
# cyl    -1.762794
# disp   -1.067523
# hp      0.275212
# drat   -0.450432
# wt      0.416595
# qsec    0.864931
# vs     -2.063273
# am     -1.966550
# gear   -0.895292
# carb    2.020059
# dtype: float64

# %%
mtcarsEDA = pd.read_csv('AutomobileEDA.csv')

mtcarsEDA
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
mtcarsEDA["drive-wheels"].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='drive-wheels'>

# %%
sns.boxplot(x = 'engine-location', y = 'price', data = mtcarsEDA)
sns.set(rc={'figure.figsize':(16,9)})

# %%
Birthweight = pd.read_csv("Birthweight_reduced_kg_R.csv")
Birthweight
# Out:
#       ID  Length  Birthweight  Headcirc  Gestation  smoker  mage  mnocig  \
# 0   1360      56         4.55        34         44       0    20       0
# 1   1016      53         4.32        36         40       0    19       0
# 2    462      58         4.10        39         41       0    35       0
# 3   1187      53         4.07        38         44       0    20       0
# 4    553      54         3.94        37         42       0    24       0
# 5   1636      51         3.93        38         38       0    29       0
# 6    820      52         3.77        34         40       0    24       0
# 7   1191      53         3.65        33         42       0    21       0
# 8   1081      54         3.63        38         38       0    18       0
# 9    822      50         3.42        35         38       0    20       0
# 10  1683      53         3.35        33         41       0    27       0
# 11  1088      51         3.27        36         40       0    24       0
# ...

# %%
from scipy.stats import ttest_1samp

ttest_1samp(Birthweight)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a1709bf8eb9d> in <module>
#       1 from scipy.stats import ttest_1samp
#       2
# ----> 3 ttest_1samp(Birthweight)
#
# TypeError: ttest_1samp() missing 1 required positional argument: 'popmean'
